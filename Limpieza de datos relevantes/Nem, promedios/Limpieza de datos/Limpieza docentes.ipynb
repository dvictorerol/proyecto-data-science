# %%
import pandas as pd
import numpy as np

# %%
asistentes = pd.read_csv("20210723_Asistentes_de_la_Educacin_ESTAB_2021_20210630_PUBL.csv", sep=";")

# %%
asistentes.columns
# Out:
# Index(['AGNO', 'RBD', 'DGV_RBD', 'NOM_RBD', 'COD_REG_RBD', 'NOM_REG_RBD_A',
#        'COD_PRO_RBD', 'COD_COM_RBD', 'NOM_COM_RBD', 'COD_DEPROV_RBD',
#        'NOM_DEPROV_RBD', 'COD_DEPE', 'COD_DEPE2', 'RURAL_RBD', 'ESTADO_ESTAB',
#        'MRUN', 'GEN_ASIS', 'FEC_NAC_ASIS', 'COD_ASIS_ESCOL', 'ID_ESCOL_TITULO',
#        'ID_ESCOL_INSTITUCION', 'FEC_TIT', 'DUR_CARRERA', 'ID_ESC_EST_INCOMP',
#        'ID_AREA_EST_INCOMP', 'ANO_SERV_SIST', 'FEC_ING_TRAB_ACTUAL',
#        'ID_PREVISION', 'ID_LUGAR_DESEMPENO', 'ID_ITC', 'ID_ITC_CORR',
#        'HORAS_CONTRATO', 'ID_ESTAMENTO', 'ID_F1', 'ANIOS_F1', 'HORAS_F1',
#        'ID_F2', 'ANIOS_F2', 'HORAS_F2', 'ID_CAPACITACION',
#        'ANIO_ULT_CAPACITACION', 'NOM_CAPACITACION', 'PERSONAS'],
#       dtype='object')

# %%
cuenta = asistentes.groupby(by = ["RBD", "NOM_RBD"]).count()

# %%
cuenta = cuenta["AGNO"].reset_index()

# %%
cuenta.rename(columns={"AGNO":"DOCENTES"}, inplace=True)

# %%
cuenta
# Out:
#          RBD                                    NOM_RBD  DOCENTES
# 0          1                    LICEO POLITECNICO ARICA        42
# 1          2                  PARVULARIO LAS ESPIGUITAS        26
# 2          4                  LICEO OCTAVIO PALMA PEREZ        45
# 3          5                   JOVINA NARANJO FERNANDEZ        51
# 4          7         L. POLI. ANTONIO VARAS DE LA BARRA        70
# ...      ...                                        ...       ...
# 10675  41833                ESCUELA DE LENGUAJE INFANTE         2
# 10676  41845      COLEGIO BOSTON COLLEGE LAGUNA DEL SOL         5
# 10677  41846                    CEIA INAPEWMA LA SERENA         2
# 10678  41859  ESCUELA BASICA COLEGIO TRIGALES DEL MAIPO        12
# 10679  41888                ESCUELA HOSPITALARIA CHILOE         1
#
# [10680 rows x 3 columns]

# %%
cuenta.to_csv('docentes_establecimiento_2021.csv', index=False)

# %%
resumen_docente = pd.read_csv("Dotacion_docente_2021.csv", sep=";")

# %%
resumen_docente
# Out:
#        AGNO    RBD  DGV_RBD                                NOM_RBD  \
# 0      2021      1        9                LICEO POLITECNICO ARICA
# 1      2021      2        7              PARVULARIO LAS ESPIGUITAS
# 2      2021      3        5    ESC. PEDRO VICENTE GUTIERREZ TORRES
# 3      2021      4        3              LICEO OCTAVIO PALMA PEREZ
# 4      2021      5        1               JOVINA NARANJO FERNANDEZ
# ...     ...    ...      ...                                    ...
# 16474  2021  41881        1             SALA CUNA GABRIELA MISTRAL
# 16475  2021  41883        8  SALA CUNA Y JARDIN INFANTIL  AMANECER
# 16476  2021  41884        6       JARDIN INFANTIL MAHAY MONTESSORI
# 16477  2021  41888        9            ESCUELA HOSPITALARIA CHILOE
# 16478  2021  41892        7       C.E.I.A. COLEGIO FORJANDO FUTURO
#
#        COD_REG_RBD NOM_REG_RBD_A  COD_PRO_RBD  COD_COM_RBD   NOM_COM_RBD  \
# 0               15           AYP          151        15101         ARICA
# 1               15           AYP          151        15101         ARICA
# 2               15           AYP          151        15101         ARICA
# 3               15           AYP          151        15101         ARICA
# 4               15           AYP          151        15101         ARICA
# ...            ...           ...          ...          ...           ...
# 16474            2         ANTOF           22         2201        CALAMA
# 16475           13            RM          131        13101      SANTIAGO
# 16476           13            RM          131        13115  LO BARNECHEA
# 16477           10         LAGOS          102        10201        CASTRO
# 16478            7         MAULE           72         7201     CAUQUENES
#
#        COD_DEPROV_RBD  ... DC_SUP_SOST  HH_SUP_SOST  DC_SUBDIR  HH_SUBDIR  \
# 0                 151  ...           0            0          0          0
# 1                 151  ...           0            0          0          0
# 2                 151  ...           0            0          0          0
# 3                 151  ...           0            0          0          0
# 4                 151  ...           0            0          0          0
# ...               ...  ...         ...          ...        ...        ...
# 16474              22  ...           0            0          0          0
# 16475             131  ...           0            0          0          0
# 16476             133  ...           0            0          0          0
# 16477             102  ...           0            0          0          0
# 16478              74  ...           0            0          0          0
#
#        DC_PROF_ENC  HH_PROF_ENC  DC_EDUC_TRAD  HH_EDUC_TRAD  DC_TOT  HH_TOT
# 0                0            0             0             0      71    2291
# 1                0            0             0             0      16     539
# 2                0            0             0             0      28    1090
# 3                0            0             0             0      64    2546
# 4                0            0             0             0      70    2629
# ...            ...          ...           ...           ...     ...     ...
# 16474            0            0             0             0       0       0
# 16475            0            0             0             0       0       0
# 16476            0            0             0             0       0       0
# 16477            0            0             0             0       3      62
# 16478            0            0             0             0       0       0
#
# [16479 rows x 47 columns]

# %%
resumen_asistentes = pd.read_csv("Resumen_Asistentes_2021.csv", sep=";")

# %%
resumen_asistentes
# Out:
#        AGNO    RBD  DGV_RBD                                NOM_RBD  \
# 0      2021      1        9                LICEO POLITECNICO ARICA
# 1      2021      2        7              PARVULARIO LAS ESPIGUITAS
# 2      2021      3        5    ESC. PEDRO VICENTE GUTIERREZ TORRES
# 3      2021      4        3              LICEO OCTAVIO PALMA PEREZ
# 4      2021      5        1               JOVINA NARANJO FERNANDEZ
# ...     ...    ...      ...                                    ...
# 16475  2021  41881        1             SALA CUNA GABRIELA MISTRAL
# 16476  2021  41883        8  SALA CUNA Y JARDIN INFANTIL  AMANECER
# 16477  2021  41884        6       JARDIN INFANTIL MAHAY MONTESSORI
# 16478  2021  41888        9            ESCUELA HOSPITALARIA CHILOE
# 16479  2021  41892        7       C.E.I.A. COLEGIO FORJANDO FUTURO
#
#        COD_REG_RBD NOM_REG_RBD_A  COD_PRO_RBD  COD_COM_RBD   NOM_COM_RBD  \
# 0               15           AYP          151        15101         ARICA
# 1               15           AYP          151        15101         ARICA
# 2               15           AYP          151        15101         ARICA
# 3               15           AYP          151        15101         ARICA
# 4               15           AYP          151        15101         ARICA
# ...            ...           ...          ...          ...           ...
# 16475            2         ANTOF           22         2201        CALAMA
# 16476           13            RM          131        13101      SANTIAGO
# 16477           13            RM          131        13115  LO BARNECHEA
# 16478           10         LAGOS          102        10201        CASTRO
# 16479            7         MAULE           72         7201     CAUQUENES
#
#        COD_DEPROV_RBD  ... N_ADMIN  N_TEC  N_SIN_DATO  JORN_PROF  JORN_PARA  \
# 0                 151  ...       0      0           0        413        920
# 1                 151  ...       0      0           0        316        484
# 2                 151  ...       0      0           0          0          0
# 3                 151  ...       0      6           0        394        612
# 4                 151  ...       0      0           0        480       1194
# ...               ...  ...     ...    ...         ...        ...        ...
# 16475              22  ...       0      0           0          0          0
# 16476             131  ...       0      0           0          0          0
# 16477             133  ...       0      0           0          0          0
# 16478             102  ...       0      0           0          0         44
# 16479              74  ...       0      0           0          0          0
#
#        JORN_AUX  JORN_ADMIN  JORN_TEC  JORN_SIN_DATO  TOT_JORN
# 0           440           0         0              0      1773
# 1           220           0         0              0      1020
# 2             0           0         0              0         0
# 3           660           0       248              0      1914
# 4           403           0         0              0      2077
# ...         ...         ...       ...            ...       ...
# 16475         0           0         0              0         0
# 16476         0           0         0              0         0
# 16477         0           0         0              0         0
# 16478         0           0         0              0        44
# 16479         0           0         0              0         0
#
# [16480 rows x 31 columns]

# %%
resumen_matricula = pd.read_csv("Resumen_Matricula_EE_Oficial_2021.csv", sep=";")

# %%
resumen_matricula["MAT_TOTAL"]
# Out:
# 0        664
# 1        170
# 2        470
# 3        974
# 4        818
#         ...
# 16493      0
# 16494      0
# 16495      0
# 16496      0
# 16497      0
# Name: MAT_TOTAL, Length: 16498, dtype: int64

# %%
evaluacion = pd.read_csv("20201104_SNED_2020_2021.csv", sep=";")

# %%
evaluacion
# Out:
#          RBD  DV_RBD                                            NOM_RBD  \
# 0          1       9                            LICEO POLITECNICO ARICA
# 1          2       7                          PARVULARIO LAS ESPIGUITAS
# 2          3       5                ESC. PEDRO VICENTE GUTIERREZ TORRES
# 3          4       3                          LICEO OCTAVIO PALMA PEREZ
# 4          5       1                           JOVINA NARANJO FERNANDEZ
# ...      ...     ...                                                ...
# 10775  41132       9                  SALA CUNA Y JARDIN INFANTIL RAYÜN
# 10776  41135       3  COLEGIO INSTITUTO DE CIENCIAS Y TECNOLOGÍA TAL...
# 10777  41173       6                         CEIA LIBRE SER MISTRALIANO
# 10778  41179       5                 ESCUELA ESPECIAL DE LENGUAJE IWOKA
# 10779  41239       2              JARDIN INFANTIL PEQUEÑOS EXPLORADORES
#
#       RBD_A1 RBD_A2  COD_DEPE  COD_DEPE2  COD_REG_RBD  COD_PRO_RBD  \
# 0                           6          5           15          151
# 1                           6          5           15          151
# 2                           6          5           15          151
# 3                           6          5           15          151
# 4                           6          5           15          151
# ...      ...    ...       ...        ...          ...          ...
# 10775                       3          2            4           41
# 10776                       3          2           13          136
# 10777                       3          2            4           41
# 10778                       3          2            4           43
# 10779                       3          2            6           61
#
#        COD_COM_RBD  ...    SUPERAR    INICIAR MEJORAR   INTEGRAR    IGUALDR  \
# 0            15101  ...  47,086687          0     100          0  85,135741
# 1            15101  ...  55,224014  90,918182     100       71,6  96,660815
# 2            15101  ...  57,854875  83,033333     100  68,133333  83,392098
# 3            15101  ...  54,284818      85,94     100         92  94,777983
# 4            15101  ...  53,757389       96,4     100  78,166667  94,336781
# ...            ...  ...        ...        ...     ...        ...        ...
# 10775         4102  ...  54,981025          0     100          0  92,875155
# 10776        13601  ...  54,158699          0     100          0  92,875155
# 10777         4105  ...  54,838602     50,905     100         66  93,992402
# 10778         4301  ...                    73     100  76,533333  92,083506
# 10779         6101  ...  54,060147  65,681818     100      63,25  92,875155
#
#       CLUSTER    INDICER SEL2020_25 SEL2020_35 SEL
# 0        1532  42,585993          2          2   3
# 1        1512  62,309953          2          2   3
# 2        1541   55,98678          2          2   3
# 3        1532  65,150122          2          2   3
# 4        1532  65,513915          2          2   3
# ...       ...        ...        ...        ...  ..
# 10775     411  52,645222          2          2   3
# 10776    1332  54,690264          2          2   3
# 10777     432   59,06899          2          2   3
# 10778     451  87,042966          2          2   3
# 10779     611  62,267704          2          2   3
#
# [10780 rows x 25 columns]
